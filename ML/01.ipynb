# %% [markdown]
# # 머신러닝

# %% [markdown]
# - 데이터를 이용하여 스스로 특성과 패턴을 찾아 학습하고 예측을 수행하는 것
#   - 지도학습 (Supervised Learning)
#   - 비지도학습 (Unsupervised Learning)
#   - 강화학습 (Reinforcement Learning)

# %% [markdown]
# ### 지도학습
#   - 데이터에 대한 `Label(명시적인 답)`이 주어진 상태에서 컴퓨터를 학습시키는 방법.
#   - 분류(classification)와 회귀(Regression)
#   - 범주형 : 카테고리형 데이터
#   - 연속형 : 수치형 데이터

# %% [markdown]
# #### 분류
# - 미리 정의된 여러 클래스 레이블 중 하나를 예측하는 것 (범주형)
# - 속성 값을 입력, 클래스 값을 출력으로 하는 모델
# - 붓꽃(iris)의 세 품종 중 하나로 분류, 암 양성 음성 중 하나로 분류 등
# - 이진분류, 다중분류

# %% [markdown]
# #### 회귀
# - 연속적인 숫자를 예측하는 것
# - 속성 값을 입력, 연속적인 실수 값을 출력하는 모델
# - 어떤 사람의 교육수준, 나이, 주거지를 바탕으로 연간 소득 예측 등
# - 예측 값의 미묘한 차이가 크게 중요하지 않음

# %% [markdown]
# ### 비지도학습 (Unsupervised Learning)
# - 데이터에 대한 Label(명시적인 답)이 없는 상태에서 컴퓨터를 학습시키는 방법
# - 데이터의 숨겨진 `특징, 구조, 패턴`을 파악하는 데 사용
# - 클러스터링(clustering)[신규가치분석], 차원축소 (Dimensionality Reduction) 등
# - ex) 이미지 감색 처리, 소비자 그룹 발견을 통한 특징
# - 신규가치분석 : 유용한 인사이트 파악

# %% [markdown]
# ### 강화학습 (Reinforcement Learning)
# - 지도학습과 비슷하지만 완전한 답(label)을 제공하지 않음.
# - 기계는 더 많은 보상을 얻을 수 있는 방향으로 행동을 학습.
# - 주로 게임이나 로봇을 학습시키는 데 많이 사용

# %% [markdown]
# ### Rule-based expert system
# - 규칙 기반 전문가 시스템 : "if"와 "else"로 하드코딩된 명령을 사용하는 시스템
