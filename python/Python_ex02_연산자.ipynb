# %% [markdown]
# ## 목표
#  - 연산자를 이해할 수 있다.
#  - 연산자의 종류를 이해하고 활용해 본다.
#  - 연산자를 이용하여 코드를 작성할 수 있다.
#
# ![image.png](attachment:4ddd54fd-5114-406d-af00-c11a3e22e261.png)

# %% [markdown]
# ### 산술연산자
#  - 더하기, 빼기, 곱하기, 나누기, 나누기(몫), 나머지

# %%
num1, num2 = 10, 8
print(num1, num2)
# Out:
# 10 8

# %%
type(num1),type(num2)
# Out:
# (int, int)

# %%
print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
print(num1 // num2) # 몫
print(num1 % num2) # 나머지
# Out:
# 18
# 2
# 80
# 1.25
# 1
# 2

# %% [markdown]
# - 산술연산자 문자열 처리

# %%
str1 = "안녕"
str2 = "하세요"

print(str1+str2) # 문자열 연결
# Out:
# 안녕하세요

# %%
# 데이터 타입이 달라도 연산 될까?
print(str1+num1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # 데이터 타입이 달라도 연산 될까?
# ----> 2 print(str1+num1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# '10안녕' 더해지게 하고 싶다면?
str(num1)+str1
# Out:
# '10안녕'

# %%
# 문자열 곱하기 
'*' * 1000
# Out:
# '*************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************
# ...

# %% [markdown]
# - input() : 키보드로 부터 입력받는 기능 / 자료형은 "str"(문자열)

# %% [markdown]
# ![image.png](attachment:607da030-c6f6-4e99-a79e-7938e5ed9c60.png)

# %%
num1 = int(input('정수를 입력하세요>> '))
num2 = int(input('정수를 입력하세요>> '))
print(f"더하기 결과: {(num1 + num2)}")
print(f"빼기 결과: {num1 - num2}")
print(f"곱하기 결과: {num1 * num2}")
print(f"나누기 결과: {(num1 / num2):.2f}")
# Out:
# 정수를 입력하세요>>  3
# 정수를 입력하세요>>  7
# 더하기 결과: 10
# 빼기 결과: -4
# 곱하기 결과: 21
# 나누기 결과: 0.43

# %% [markdown]
# ![image.png](attachment:10aa506e-842e-4be2-9b46-3b5f9ce13557.png)

# %%
p_score = int(input("python 점수 입력>> "))
m_score = int(input("머신러닝 점수 입력>> "))
d_score = int(input("딥러닝 점수 입력>> "))
print("합계 : {}".format(p_score+m_score+d_score))
print("평균 : {}".format((p_score+m_score+d_score)/3))
# Out:
# python 점수 입력>>  100
# 머신러닝 점수 입력>>  80
# 딥러닝 점수 입력>>  60
# 합계 : 240
# 평균 : 80.0

# %%
print(f"합계 : {p_score + m_score + d_score}")
print(f"합계 : {(p_score + m_score + d_score)/3}")
# Out:
# 합계 : 240
# 합계 : 80.0

# %% [markdown]
# ![image.png](attachment:5929570e-ce88-452c-917e-78ccc6bf7191.png)

# %%
print("*"*10+" 연산하기 "+"*"*10)
num1 = int(input("정수입력 >> "))
num2 = int(input("정수입력 >> "))
cal = input("+ 연산자입력 >>")
print("{} {} {} = {} ".format(num1,cal,num2,num1+num2))
# Out:
# ********** 연산하기 **********
# 정수입력 >>  10
# 정수입력 >>  20
# + 연산자입력 >> +
# 10 + 20 =  30

# %% [markdown]
# ### 지수연산자
#  - 제곱, 세제곱, ~~승

# %%
num2 = 2
power = int(input())
print(f"2의 {power}승 : {num2**power}")
# Out:
#  6
# 2의 6승 : 64

# %%
num2 = int(input())
power = int(input())
print(f"{num2}의 {power}승 : {num2**power}")
# Out:
#  3
#  7
# 3의 7승 : 2187

# %% [markdown]
# ### 대입(복합) 연산자
#  - 대입 : = (같다 : ==)
#  - 복합대입 : +=,-=,*=,/=

# %%
a = 3
b = "신난다!"
print(a,b)
# Out:
# 3 신난다!

# %%
# +=
a += 3 # a = a + 3
print(a)
# Out:
# 6

# %%
# -=
a -= 1 # a = a -1
print(a)
# Out:
# 5

# %% [markdown]
# - 치환 : 두개의 공간에 있는 데이터의 위치를 바꾸는 개념

# %%
# 1 
a = 3
b = 5
print(a,b)

temp = a
a = b
b = temp 

print(a,b)
# Out:
# 3 5
# 5 3

# %%
# 2
a = 3
b = 5
print(a,b)

a,b = b,a
print(a,b)
# Out:
# 3 5
# 5 3

# %% [markdown]
# ### 비교연산자
#  - 크거나 같은지를 묻는 연산자 : <, <=, >,
#  - 같거나 다르거나 : ==, !=
#  - 결과값 : True(1), False(0)

# %%
a,b,c = 3,6 # 데이터의 개수가 일치하지 않으면 에러 발생
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 a,b,c = 3,6,
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
a,b = 3,7

print(a > b)
print(a < b)
print(a == b)
print(a != b)
# Out:
# False
# True
# False
# True

# %% [markdown]
# ### 논리연산자
#  - not : 원래의 결과를 반전시키는 키워드
#  - and, or : 논리에 대한 정보를 연결
#  - and : 두 개의 논리가 True(1) 에 해당하면 True를 출력하는 연산자
#  - or : 두 개의 논리 중 한개라도 True(1) 에 해당하면 True를 출력하는 연산자

# %%
result = (a != b)
result
# Out:
# True

# %%
not result
# Out:
# False

# %%
(3>2) and (5>1) ,(3>2) or (5>1)
# Out:
# (True, True)

# %%
(3>2) and (5<1) ,(3>2) or (5<1)
# Out:
# (False, True)

# %% [markdown]
# ### 멤버연산자
#  - in : 찾고자 하는 값이 포함되어 있으면 True
#  - not in : 찾고자 하는 값이 포함되어있지 않으면 True

# %%
str1 = "오늘 점심 뭐 먹어?"
"?" in str1
# Out:
# True

# %%
"!" in str1
# Out:
# False

# %%
"?" not in str1
# Out:
# False

# %%
"!" not in str1 #str1안에 "!" 없지? => 없으므로 True
# Out:
# True

# %%
"참외" in ["딸기","수박","참외"],"참외" not in ["딸기","수박","참외"]
# Out:
# (True, False)

# %%
"멜론" in ["딸기","수박","참외"], "멜론" not in ["딸기","수박","참외"]
# Out:
# (False, True)

# %% [markdown]
# ### 삼항연산자
#  - a / if 논리 / else b
#  - 논리 먼저 확인 > True : a, False : b

# %%
num = int(input("시험점수 입력 >>"))


result = "합격" if num >= 60 else "불합격"
print(f"{result} 하셨습니다.")
# Out:
# 시험점수 입력 >> 70
# 합격 하셨습니다.

# %% [markdown]
# ![image.png](attachment:d97c2756-7669-48a5-8f22-81fae3d6f03b.png)

# %%
a = int(input("정수입력 >> "))
b = int(input("정수입력 >> "))

print(f"a : {a}") if a>b else print(f"b : {b}")
# Out:
# 정수입력 >>  3
# 정수입력 >>  10
# b : 10

# %%
a = int(input("정수입력 >> "))
b = int(input("정수입력 >> "))

result = f"a : {a}") if a>b else f"b : {b}") 
print(f"a : {a}") if a>b else print(f"b : {b}")
# Out:
# 정수입력 >>  3
# 정수입력 >>  10
# b : 10

# %% [markdown]
# ![image.png](attachment:80a03c2a-11ab-4ea3-9939-45216887f927.png)

# %%
num1 = int(input("첫번째 정수 입력 >>"))
num2 = int(input("두번째 정수 입력 >>"))

print("두 수의 차 : ", num1-num2) if num1>num2 else print("두 수의 차 : " ,num2-num1)
# Out:
# 첫번째 정수 입력 >> 33
# 두번째 정수 입력 >> 5
# 두 수의 차 :  28

# %% [markdown]
# ![image.png](attachment:274cfe52-e991-4b07-aaef-40da0cdec51f.png)

# %%
num = int(input("정수 입력 >>"))

print(f"{num}는(은) 짝수입니다.") if num%2==0 else print(f"{num}는(은) 홀수입니다.")
# Out:
# 정수 입력 >> 33
# 33는(은) 홀수입니다.

# %% [markdown]
# ![image.png](attachment:7d0345b9-741f-4776-9d5e-5b847e93e977.png)

# %%
ball = int(input("농구공 수 입력 >> "))

box = int(ball/5)

result = box if ball%5==0 else box + 1

print(f"필요한 상자의 수 : {result}박스")
# Out:
# 농구공 수 입력 >>  20
# 필요한 상자의 수 : 4박스

# %%
ball = int(input("농구공 수 입력 >> "))

result = ball//5 if ball%5==0 else ball//5+1

print(f"필요한 상자의 수 : {result} 박스")
# Out:
# 농구공 수 입력 >>  20
# 필요한 상자의 수 : 4 박스

# %% [markdown]
# ![image.png](attachment:799d53d6-9e9e-4589-849f-2e88e4617d62.png)

# %%
worktime = int(input('근무시간 입력 >> '))

salary = 15000*(worktime-8) + 10000*8 if worktime>8 else 10000*worktime  

print(f"총 지급액은 : {salary}입니다.")
# Out:
# 근무시간 입력 >>  11
# 총 지급액은 : 125000입니다.

# %%
worktime = int(input('근무시간 입력 >> '))
basic_salary = 10000
basic_time = 8
c = 1.5

salary = int(c*basic_salary*(worktime-basic_time) + basic_salary * basic_time) if worktime>basic_time else int(basic_salary*worktime)

print(salary)
# Out:
# 근무시간 입력 >>  11
# 125000

# %% [markdown]
# - 처음에는 worktime을 그대로 곱해서 금액이 제대로 나오지 않았음.
#
# - worktime을 10000으로 그대로 곱해버리면, 그시간을 모두 10000원으로 계산하게 됨. 따라서
#   ```
#   15000*(worktime-8) + 10000*8
#   ```
#   worktime그대로를 곱하는 게 아니라 8시간을 곱해야함.

# %% [markdown]
# ![image.png](attachment:e615ca8d-a7a5-4560-b4ba-dd356803a4c5.png)

# %%
a = int(input("DB >>"))
b = int(input("전자계산기 구조 >>"))
c = int(input("운영체제 >>"))
d = int(input("데이터통신 >>"))
e = int(input("소프트웨어공학 >>"))

pf = "불합격입니다!" if ((a<8) or (b<8) or (c<8) or (d<8) or (e<8)) or (a+b+c+d+e < 60) else "합격입니다!"

print(pf)
# Out:
# DB >> 5
# 전자계산기 구조 >> 20
# 운영체제 >> 20
# 데이터통신 >> 20
# 소프트웨어공학 >> 20
# 불합격입니다!

# %%
a = int(input("DB >>"))
b = int(input("전자계산기 구조 >>"))
c = int(input("운영체제 >>"))
d = int(input("데이터통신 >>"))
e = int(input("소프트웨어공학 >>"))

pf = "합격입니다" if ((a>=8) and (b>=8) and (c>=8) and (d>=8) and (e>=8)) and (a+b+c+d+e >=60) else "불합격입니다!"

print(pf)
# Out:
# DB >> 8
# 전자계산기 구조 >> 20
# 운영체제 >> 20
# 데이터통신 >> 20
# 소프트웨어공학 >> 20
# 합격입니다

# %% [markdown]
# - 처음에 불합격 조건을 만들 때,"각 과목별 한개라도 과락할경우" 라는 조건을 잘못파악해서 and로 연결했음. 과락은 하나라도 8보다 작으면 불합격임.
# ```
# pf = "불합격입니다!" if ((a<8) or (b<8) or (c<8) or (d<8) or (e<8)) or (a+b+c+d+e < 60) else "합격입니다!"
# ```
# - and 연산은 모든 것을 다 만족해야 True임
#
# - 처음부터 합격 기준에서 생각하는 게 직관적으로 훨씬 편했음!
