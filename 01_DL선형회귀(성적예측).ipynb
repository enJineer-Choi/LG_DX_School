# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 작업 디렉토리 설정 (본인 경로로 변경)
# %cd /content/drive/Othercomputers/LG DX 노트북/LG_Dx_School/Deep Learning
# !pwd
# Out:
# /content/drive/Othercomputers/LG DX 노트북/LG_Dx_School/Deep Learning
# /content/drive/Othercomputers/LG DX 노트북/LG_Dx_School/Deep Learning

# %%
## library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./data/student-mat.csv",sep=';')

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# - 정답 데이터는 G3 (3학년 데이터를 맞추는 모델링 필요)
#
# 해당 데이터는 허깅페이스 [https://huggingface.co/datasets/scikit-learn/student-alcohol-consumption]에서 가져온 데이터

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %% [markdown]
# | 변수명 | 설명 | 타입 | 값 범위 / 의미 |
# |--------|------|------|----------------|
# | school | 학교 | 범주형 | GP(Gabriel Pereira), MS(Mousinho da Silveira) |
# | sex | 성별 | 범주형 | F(여), M(남) |
# | age | 나이 | 수치형 | 15 ~ 22 |
# | address | 거주 지역 | 범주형 | U(도시), R(농촌) |
# | famsize | 가족 규모 | 범주형 | LE3(3명 이하), GT3(3명 초과) |
# | Pstatus | 부모 동거 여부 | 범주형 | T(같이 거주), A(별거) |
# | Medu | 어머니 교육 수준 | 수치형 | 0~4 (높을수록 고학력) |
# | Fedu | 아버지 교육 수준 | 수치형 | 0~4 |
# | Mjob | 어머니 직업 | 범주형 | teacher, health, services, at_home, other |
# | Fjob | 아버지 직업 | 범주형 | teacher, health, services, at_home, other |
# | reason | 학교 선택 이유 | 범주형 | home, reputation, course, other |
# | guardian | 보호자 | 범주형 | mother, father, other |
# | traveltime | 통학 시간 | 수치형 | 1(<15분) ~ 4(1시간 이상) |
# | studytime | 주당 학습 시간 | 수치형 | 1(<2h) ~ 4(>10h) |
# | failures | 과거 낙제 횟수 | 수치형 | 0~3 이상 |
# | schoolsup | 학교 보충수업 여부 | 범주형 | yes/no |
# | famsup | 가족 학습 지원 여부 | 범주형 | yes/no |
# | paid | 유료 과외 여부 | 범주형 | yes/no |
# | activities | 방과후 활동 여부 | 범주형 | yes/no |
# | nursery | 유치원 경험 | 범주형 | yes/no |
# | higher | 대학 진학 희망 | 범주형 | yes/no |
# | internet | 집 인터넷 여부 | 범주형 | yes/no |
# | romantic | 연애 여부 | 범주형 | yes/no |
# | famrel | 가족 관계 만족도 | 수치형 | 1~5 (높을수록 좋음) |
# | freetime | 여가 시간 | 수치형 | 1~5 |
# | goout | 외출 빈도 | 수치형 | 1~5 |
# | Dalc | 평일 음주량 | 수치형 | 1~5 |
# | Walc | 주말 음주량 | 수치형 | 1~5 |
# | health | 건강 상태 | 수치형 | 1~5 |
# | absences | 결석 횟수 | 수치형 | 0~93 |
# | G1 | 1학기 성적 | 수치형 | 0~20 |
# | G2 | 2학기 성적 | 수치형 | 0~20 |
# | G3 | 최종 성적 (타겟) | 수치형 | 0~20 |

# %% [markdown]
# ### 문제와 정답으로 분리
# - 입력 특성 : 1개 (studytime)
# - 정답 특성 : 1개 (G3)

# %%
X = data[['studytime']] # 문제데이터는 항상 2차원이어야한다!
y = data['G3']

# %%
X.shape,y.shape
# Out:
# ((395, 1), (395,))

# %%
X
# Out:
#      studytime
# 0            2
# 1            2
# 2            2
# 3            3
# 4            2
# ..         ...
# 390          2
# 391          1
# 392          1
# 393          1
# 394          1
#
# [395 rows x 1 columns]

# %% [markdown]
# - 학습용, 평가용 데이터로 분리
# - trian_test_split
#     - 평가용 데이터 20%
#     - 랜덤 규칙 : 27

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=27)

# %%
#크기확인
print('훈련용 문제: ',X_train.shape)
print('훈련용 답: ',y_train.shape)
print('테스트용 문제: ',X_test.shape)
print('테스트용 답: ',y_test.shape)
# Out:
# 훈련용 문제:  (316, 1)
# 훈련용 답:  (316,)
# 테스트용 문제:  (79, 1)
# 테스트용 답:  (79,)

# %% [markdown]
# ### 모델링
# 1. 모델 객체생성 (정의)
# 2. 모델 학습 (fit)
# 3. 모델 예측 (predict)
# 4. 모델 평가 (mean_squared_error)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# 1. 모델 객체 생성

# %%
model = LinearRegression()

# %% [markdown]
# 2. 모델 학습

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# 3. 모델 예측

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 23.906884708034738

# %%
sum((y_test-y_pred)**2)/len(y_pred)
# Out:
# 23.906884708034735
